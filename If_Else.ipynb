# %% [markdown]
# <a href="https://colab.research.google.com/github/wasimciit/Python_Programming_SP26/blob/main/If_Else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **If-Else Conditions**

# %% [markdown]
# - What is a Conditional Statement?
#
# A conditional statement allows a program to make decisions based on a condition.
#
# - In simple words:
#
# “If something is true → do this, otherwise → do something else”

# %%
# Basic syntex of if
if condition:
  # code to execute if the condition is true
# Out:
#   File "/tmp/ipykernel_3851/1128809657.py", line 3
#     # code to execute if the condition is true
#                                               ^
# SyntaxError: incomplete input

# %%
# example
age=int(input("Enter your age "))

if age>=18:
  print("You are eligible for vote")
# Out:
# Enter your age 17

# %%
age=7
if age>=18:
  print("You are eligible for vote")

# %%
age=int(input("Enter your age "))

if age>=18:
  print("You are eligible for vote")
else:
  print("You are not eligible for Vote ")
# Out:
# Enter your age 21
# You are eligible for vote

# %%
age=19
if age>=18:
  print("You are eligible for vote")
else:
  print("You are not eligible for Vote ")
# Out:
# You are eligible for vote

# %%
number=int(input("Enter a number "))
if number%2==0:
  print("The Number is even")
else:
  print("The Number is odd")
# Out:
# Enter a number 800
# The Number is even

# %%
number=91
if number%2==0:
  print("The Number is even")
else:
  print("The Number is odd")
# Out:
# The Number is odd

# %%
# if-elif-else
number=int(input("Enter a number "))
if number>0:
  print("The Number is positive")
elif number==0:
  print("The number is zero")
else:
  print("The Number is negative")
# Out:
# Enter a number -3
# The Number is negative

# %%
marks=int(input("Enter your marks"))
if marks>=50:
  print("Pass")
else:
  print("Fail")
# Out:
# Enter your marks49
# Fail

# %%
marks=int(input("Enter your marks"))
if marks>=80:
  print("Grade is A")
elif marks>=70:
  print("Grade is B+")
elif marks>=60:
  print("Grade is B")
elif marks>=50:
  print("Grade is C")
else:
  print("Grade is D")
# Out:
# Enter your marks49
# Grade is D

# %%
age=17
citizen=False
if age>=18:
  if citizen==True:
    print("Eligible for vote")
  else:
    print("Not a Citizen")
else:
  print("Not Eligible for Vote")
# Out:
# Not Eligible for Vote

# %%
# Write a program to check if a number is positive.
num=int(input("Enter a number"))
if num>0:
  print("The number is positive")
# Out:
# Enter a number9
# The number is positive

# %%
# Check whether a number is even or odd.
num=int(input("Enter a number"))
if num%2==0:
  print("The number is even")
else:
  print("The number is odd")
# Out:
# Enter a number99
# The number is odd

# %%
# Write a program to check if a number is divisible by 5
num=int(input("Enter a number"))
if num%5==0:
  print("The number is divisible by 5")
else:
  print("The number is not divisible by 5")
# Out:
# Enter a number74
# The number is not divisible by 5

# %%
# Check whether a number is greater than 100.
num=int(input("Enter a number"))
if num>100:
  print("The number is greater than 100")
else:
  print("The number is not greater than 100")
# Out:
# Enter a number99
# The number is not greater than 100

# %%
# Write a program to assign grades:

# 80+ → A
# 60–79 → B
# 50–59 → C
# Below 50 → Fail
marks=int(input("Enter your marks"))
if marks>=80:
  print("Grade is A")
elif marks>=60:
  print("Grade is B")
elif marks>=50:
  print("Grade is C")
else:
  print("Grade is Fail")
# Out:
# Enter your marks49
# Grade is Fail

# %%
# Check the largest of two numbers.
a=int(input("Enter first number"))
b=int(input("Enter second number"))
if a>b:
  print("first is greater number")
else:
  print("second is greater number")
# Out:
# Enter first number4
# Enter second number5
# second is greater number

# %%
# Write a program to check if a number is positive, negative, or zero.
num=int(input("Enter a number"))
if num>0:
  print("The number is positive")
elif num<0:
  print("The number is negative")
else:
  print("The number is zero")
# Out:
# Enter a number-1
# The number is negative

# %%
# Create a simple login system (username & password check).
username=input("Enter User name:")
password=input("Enter the Password:")
if username=="waseem" and password=="1234":
  print("Login successful")
else:
  print("Kaka username and password ma say koi ik match ni kar rha. chal dobara enter kar")
# Out:
# Enter User name:waseem
# Enter the Password:1234
# Login successful

# %%
# Bank System:
# If balance ≥ withdrawal → allow
# Otherwise → show insufficient funds
balance=50000
withdraw=int(input("Enter withdrawal amount"))
if withdraw<=balance:
  print("Withdrawal Allow")
else:
  print("insufficient funds")
# Out:
# Enter withdrawal amount51000
# insufficient funds

# %%
# Student Scholarship:
# CGPA ≥ 3.5 AND income < 50000 → Eligible
# Else → Not eligible

# %% [markdown]
# 1. Student Scholarship:
#
# Marks ≥ 85 AND income < 50000 → Eligible
#
# Else → Not eligible
#
# 2. Traffic Fine System:
#
# Speed > 100 → Heavy fine
#
# Speed 60–100 → Warning
#
# Otherwise → Safe
#
# 3. Electricity Bill:
#
# Units ≤ 100 → Rs. 5/unit
#
# 101–200 → Rs. 8/unit
#
# Above 200 → Rs. 10/unit
#
# 4. Write a program to check if three numbers can form a triangle.
#
# 5. Create a grading system with nested conditions (distinction, merit, pass, fail).
#
# 6. Write a decision system for hiring:
# Experience ≥ 3 years AND skills ≥ 2 → Selected
#
# 7. Develop a mini calculator using if-else.
#
# 8. Predict employee attrition risk using conditions (based on satisfaction, salary, workload).
