# %% [markdown]
# # Lecture 01

# %% [markdown]
# ## Syntex
#
# - Python syntax can be executed by writing directly in the Command Line

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hi, i am a python programmer. I am learning python to become a better programmer.")
# Out:
# Hi, i am a python programmer. I am learning python to become a better programmer.

# %%
print("$"*60)
# Out:
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$

# %%
print("This is a simple Python script.","do you like it?")
# Out:
# This is a simple Python script. do you like it?

# %% [markdown]
# ## Indentation
#
# - Indentation refers to the spaces at the beginning of a code line.
#
# Where in other programming languages the indentation in code is for readability only, the indentation in Python is very important.
#
# Python uses indentation to indicate a block of code.

# %%
if 5>2:
    print("Five is greater than two!")
# Out:
# Five is greater than two!

# %%
if 5>3:
print("5 is greater than 3")
# Out:
#   Cell In[6], line 2
#     print("5 is greater than 3")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %% [markdown]
# - The number of spaces is up to you as a programmer, the most common use is four, but it has to be at least one.

# %%
if 5>2:
 print("Five is greater than two!")
# Out:
# Five is greater than two!

# %%
if 5>3:
        print("5 is greater than 3")
# Out:
# 5 is greater than 3

# %%
if 5 > 2:
 print("Five is greater than two!") 
if 5 > 2:
        print("Five is greater than two!")
# Out:
# Five is greater than two!
# Five is greater than two!

# %% [markdown]
# ## Comments
#
# - Python has commenting capability for the purpose of in-code documentation.
#
# Comments start with a #, and Python will render the rest of the line as a comment:

# %%
# my first program in python
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## Markdown Language

# %%
# Heading 1
## Heading 2
### Heading 3
#### Heading 4
##### Heading 5
###### Heading 6

# %% [markdown]
# *python*

# %%
*Italic* or _Italic_
**Bold** or __Bold__
***Bold & Italic*** or ___Bold & Italic___
# Out:
#   Cell In[12], line 1
#     *Italic* or _Italic_
#              ^
# SyntaxError: invalid syntax

# %%
- Item 1
- Item 2
  - Subitem 1
  - Subitem 2
* Another style
+ Another style
# Out:
#   Cell In[13], line 1
#     - Item 1
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# - item 1
# - item 2
#   - item 2.1

# %% [markdown]
# * learning

# %% [markdown]
# + learning
#   + Learning

# %% [markdown]
# ## Python Statements
#
# A computer program is a list of "instructions" to be "executed" by a computer.
#
# In a programming language, these programming instructions are called statements.
#
# The following statement prints the text "Python is fun!" to the screen:

# %%
print("Python is fun!")
# Out:
# Python is fun!

# %%
# many statements
print("Python is fun!")
print("Python is fun!")
print("Python is fun!")
# Out:
# Python is fun!
# Python is fun!
# Python is fun!

# %%
print("This is a simple Python script."); print("do you like it?") ; print(" Python is fun!")
# Out:
# This is a simple Python script.
# do you like it?
#  Python is fun!

# %%
print("Hello World!", end=" ")
print("I will print on the same line.")
# Out:
# Hello World! I will print on the same line.

# %%
print("Hello World!")
print("I will print on the same line.")
# Out:
# Hello World!
# I will print on the same line.

# %%
print("Hello World!", end=" $$ ")
print("I will print on the same line.")
# Out:
# Hello World! $$ I will print on the same line.

# %%
print("Hello World", end="!")
print("I will print on the same line.")
# Out:
# Hello World!I will print on the same line.
